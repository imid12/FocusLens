# %% [markdown]
# # Exploration Notebook
#
# This notebook serves as a starting point for exploring the data and performing initial analyses. You can use this notebook to document your findings and visualize data insights as you progress through your exploratory data analysis (EDA) phase.

# %%
# Insert your exploratory code here
